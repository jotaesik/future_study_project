# %%
import pandas as pd

# %%
country_make_data = pd.read_csv('./data/한국광해광업공단_광종별 국가별 생산량_20221231.csv',encoding='euc-kr')
# 2011 ~ 2023

# %%
country_make_data
# Out:
#        광종       품목       대륙                    국가  단위  2011 생산량  2012 생산량  \
# 0    알루미늄  bauxite   EUROPE  Bosnia & Herzegovina  천톤   561.354   800.316
# 1    알루미늄  bauxite   EUROPE               Croatia  천톤     0.000     0.000
# 2    알루미늄  bauxite   EUROPE                France  천톤    80.800    90.129
# 3    알루미늄  bauxite   EUROPE                Greece  천톤  2324.000  1815.328
# 4    알루미늄  bauxite   EUROPE               Hungary  천톤   277.800   255.100
# ..    ...      ...      ...                   ...  ..       ...       ...
# 720    아연     slab  AMERICA                Canada  천톤   662.151   648.619
# 721    아연     slab  AMERICA                Mexico  천톤   322.116   323.569
# 722    아연     slab  AMERICA                  Peru  천톤   313.714   319.280
# 723    아연     slab  AMERICA                U.S.A.  천톤   248.000   261.000
# 724    아연     slab  OCEANIA             Australia  천톤   517.000   508.000
#
#      2013 생산량  2014 생산량  2015 생산량  2016 생산량  2017 생산량  2018 생산량  2019 생산량  \
# ...

# %%
country_make_data["광종"].unique()
# Out:
# array(['알루미늄', '안티모니', '카드뮴', '코발트', '동', '금', '연', '몰리브덴', '니켈', '은',
#        '주석', '아연'], dtype=object)

# %%
nickel_country_spent = country_spent_data[country_spent_data["광종"]=="니켈"]

# %%
nickel_country_spent
# Out:
#      광종       품목       대륙                    국가  단위  2011 소비량  2012 소비량  \
# 224  니켈  refined   EUROPE               Austria  천톤     9.334     8.391
# 225  니켈  refined   EUROPE               Belgium  천톤    29.794    18.827
# 226  니켈  refined   EUROPE              Bulgaria  천톤     0.157     0.125
# 227  니켈  refined   EUROPE        Czech Republic  천톤     3.595     1.891
# 228  니켈  refined   EUROPE               Denmark  천톤     0.046     0.189
# 229  니켈  refined   EUROPE               Finland  천톤    29.002    25.141
# 230  니켈  refined   EUROPE                France  천톤    29.674    27.014
# 231  니켈  refined   EUROPE               Germany  천톤    88.404    88.790
# 232  니켈  refined   EUROPE                Greece  천톤     0.180     0.180
# 233  니켈  refined   EUROPE               Hungary  천톤     0.115     0.119
# 234  니켈  refined   EUROPE                 Italy  천톤    65.773    64.691
# 235  니켈  refined   EUROPE             Macedonia  천톤     1.200     1.200
# ...

# %%
nickel_country_spent.to_csv("니켈국가별소비량_2011_2023csv", index = False)

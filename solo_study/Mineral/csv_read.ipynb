# %%
import pandas as pd
w_data = pd.read_csv('./data/한국광해광업공단_텅스텐가격예측데이터_20240520.csv',encoding='euc-kr')
# usd/mtu는 1000킬로그램 당 usd가격
# 3개월 단위 2008-01-01 ~ 2026-10-01


co_data = pd.read_csv('./data/한국광해광업공단_코발트가격예측데이터_20240520.csv',encoding='euc-kr')
# 3개월 단위 2008-01-01 ~ 2026-10-01	
co_stable_data = pd.read_csv('./data/한국광해광업공단_수급안정화지수_코발트_20240520.csv',encoding='euc-kr')
# 1개월 단위 2018-01-01 ~ 2024-05-01	
co_danger_data = pd.read_csv('./data/한국광해광업공단_코발트 시장위험지수_20240520.csv',encoding='euc-kr')
# 1개월 단위 2011-02-01 ~ 2024-05-01	
# isna() 22개
# usd/lb는 0.45킬로그램당 usd가격




mn_data = pd.read_csv('./data/한국광해광업공단_망간가격예측데이터_20240520.csv',encoding='euc-kr')
# 3개월 단위 2008-01-01 ~ 2026-10-01
# usd/ton은 1000킬로그램당 usd가격



li_data = pd.read_csv('./data/한국광해광업공단_리튬가격예측데이터_20240520.csv',encoding='euc-kr')
# 3개월 단위 2008-01-01 ~ 2026-10-01
li_stable_data = pd.read_csv('./data/한국광해광업공단_수급안정화지수_리튬_20240520.csv',encoding='euc-kr')
# 1개월 단위 2008-01-01 ~ 2024-05-01
li_danger_data = pd.read_csv('./data/한국광해광업공단_리튬 시장위험지수_20240520.csv',encoding='euc-kr')
# 1개월 단위 2015-01-01 ~ 2024-05-01	




# RMB/kg 는 킬로그램당 RMB 중국 위안화폐 =>미국USD로 변환
ni_stable_data = pd.read_csv('./data/한국광해광업공단_수급안정화지수_니켈_20240520.csv',encoding='euc-kr')
# 1개월 단위 2018-01-01 ~ 2024-05-01	



country_io_data = pd.read_csv('./data/한국광해광업공단_국가별 광종 수출입 현황_20231231.csv',encoding='euc-kr')
# 2021 2022



kor_io_data = pd.read_csv('./data/한국광해광업공단_광종별 국내 수출입 현황_20231231.csv',encoding='euc-kr')
# 2021 2022



country_spent_data = pd.read_csv('./data/한국광해광업공단_광종별 소비현황_20231231.csv',encoding='euc-kr')
#2011 ~ 2023



country_make_data = pd.read_csv('./data/한국광해광업공단_광종별 국가별 생산량_20221231.csv',encoding='euc-kr')
# 2011 ~ 2023

# %%
country_spent_data
# Out:
#        광종       품목       대륙           국가  단위  2011 소비량  2012 소비량  2013 소비량  \
# 0    알루미늄  refined   EUROPE      Austria  천톤   293.867   253.700   201.000
# 1    알루미늄  refined   EUROPE      Belarus  천톤    10.200    10.200    10.200
# 2    알루미늄  refined   EUROPE      Belgium  천톤   382.312   344.280   236.780
# 3    알루미늄  refined   EUROPE     Bulgaria  천톤    52.188    53.527    60.645
# 4    알루미늄  refined   EUROPE      Croatia  천톤    77.771    83.684    76.755
# ..    ...      ...      ...          ...  ..       ...       ...       ...
# 405    아연     slab  AMERICA       U.S.A.  천톤   939.000   892.000   935.000
# 406    아연     slab  AMERICA      Uruguay  천톤     0.000     0.520     0.514
# 407    아연     slab  AMERICA    Venezuela  천톤    10.430     6.656     9.014
# 408    아연     slab  OCEANIA    Australia  천톤   207.319   116.293   180.000
# 409    아연     slab  OCEANIA  New Zealand  천톤    11.023     9.275     8.844
#
# ...

# %%
country_spent_data["광종"].unique()
# Out:
# array(['알루미늄', '카드뮴', '동', '연', '니켈', '주석', '아연'], dtype=object)

# %%
country_spent_data[country_spent_data["광종"] =="텅스텐"]
# Out:
# Empty DataFrame
# Columns: [광종, 품목, 대륙, 국가, 단위, 2011 소비량, 2012 소비량, 2013 소비량, 2014 소비량, 2015 소비량, 2016 소비량, 2017 소비량, 2018 소비량, 2019 소비량, 2020 소비량, 2021 소비량, 2022 소비량, 2023 소비량]
# Index: []

# %% [markdown]
# 전세계 전기차 생산량 비중 미래
# 태양광 pv 설치 => 풍력발전은?
# 배터리
# 관련 뉴스
# 핵심 광물 수입 의존국
# 특종 국가의 독점
# 광물의 수요 증가률
# 특정국가가 전기차 생산량 비중을 차지하는가?
# 경기침체나, 은행위기 확산, 공급 증대
# 2023년 초 발생했던 공급측 국가들의 문제 // 광산 공급중단,폭우,생산차질
# 특정국가의 가격지수가 하락세인가? 상승세인가?
# 리튬의 잠재수요가 건조하게 유지되고 있으나, 왜 보이는 수요증가폭은 적은가?
# 런던금속거래소의 재고량 런던금속거래소(LME), 시카고상업거래소(CME), 상하이선물거래소(SHFE)
# 에너지 기술비용이 크게 절감하였응나, 총비용에서 원자재가 차지하는 비용은 증가 ex)배터리 원가에서 양극재가 차지하는 비중
# 광물 개발기업의 성장선
# 리튬 탐사에 투자하는 비용
# EU 「핵심원자재법(안)」에서 역내 공급 모니터링, 스트레스 테스트
# 이게 뉴스도 땡겨올수있으면 좋은
# 전기차 보급률이 높은 나라는 어디일까
#
# 광물공사??

# %% [markdown]
# 남은 나라의 광물 비축량
# 국내비축확보
# 재자원화
# 국내수요기업정보
